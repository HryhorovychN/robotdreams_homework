# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\cv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1
plt.show()

# %%
# Data normalization
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the data
x_train = x_train.reshape((-1, 28, 28, 1))
x_test = x_test.reshape((-1, 28, 28, 1))

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128, activation="relu")(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

# Compile the model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
epochs = 50
batch_size = 64
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

# Plot the history
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121)
    plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True)
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])

    plt.subplot(122)
    plt.plot(epochs, h['accuracy'], '.-', epochs, h['val_accuracy'], '.-')
    plt.grid(True)
    plt.xlabel('epochs')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\cv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\cv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\cv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\cv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 938/938 [==============================] - 43s 43ms/step - loss: 0.3924 - accuracy: 0.8598 - val_loss: 0.3328 - val_accuracy: 0.8778
# Epoch 2/50
# 938/938 [==============================] - 39s 41ms/step - loss: 0.2597 - accuracy: 0.9054 - val_loss: 0.2937 - val_accuracy: 0.8905
# Epoch 3/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.2117 - accuracy: 0.9216 - val_loss: 0.2791 - val_accuracy: 0.8997
# Epoch 4/50
# 938/938 [==============================] - 39s 41ms/step - loss: 0.1746 - accuracy: 0.9349 - val_loss: 0.2834 - val_accuracy: 0.9033
# Epoch 5/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.1447 - accuracy: 0.9467 - val_loss: 0.2867 - val_accuracy: 0.9085
# Epoch 6/50
# 938/938 [==============================] - 38s 41ms/step - loss: 0.1191 - accuracy: 0.9561 - val_loss: 0.2946 - val_accuracy: 0.9065
# Epoch 7/50
# 938/938 [==============================] - 40s 43ms/step - loss: 0.0962 - accuracy: 0.9655 - val_loss: 0.3166 - val_accuracy: 0.9071
# Epoch 8/50
# 938/938 [==============================] - 40s 43ms/step - loss: 0.0793 - accuracy: 0.9715 - val_loss: 0.3324 - val_accuracy: 0.9104
# Epoch 9/50
# 938/938 [==============================] - 40s 42ms/step - loss: 0.0655 - accuracy: 0.9765 - val_loss: 0.3822 - val_accuracy: 0.9072
# Epoch 10/50
# 938/938 [==============================] - 43s 46ms/step - loss: 0.0496 - accuracy: 0.9822 - val_loss: 0.3976 - val_accuracy: 0.9039
# Epoch 11/50
# 938/938 [==============================] - 39s 42ms/step - loss: 0.0415 - accuracy: 0.9855 - val_loss: 0.4092 - val_accuracy: 0.9071
# Epoch 12/50
# 938/938 [==============================] - 40s 43ms/step - loss: 0.0336 - accuracy: 0.9886 - val_loss: 0.4372 - val_accuracy: 0.9075
# Epoch 13/50
# 938/938 [==============================] - 39s 42ms/step - loss: 0.0309 - accuracy: 0.9890 - val_loss: 0.4767 - val_accuracy: 0.9059
# Epoch 14/50
# 938/938 [==============================] - 39s 41ms/step - loss: 0.0233 - accuracy: 0.9921 - val_loss: 0.4867 - val_accuracy: 0.9042
# Epoch 15/50
# 938/938 [==============================] - 38s 41ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.5138 - val_accuracy: 0.9033
# Epoch 16/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.5484 - val_accuracy: 0.9079
# Epoch 17/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.5589 - val_accuracy: 0.9075
# Epoch 18/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.5911 - val_accuracy: 0.9016
# Epoch 19/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.6039 - val_accuracy: 0.9060
# Epoch 20/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.6301 - val_accuracy: 0.9043
# Epoch 21/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.6523 - val_accuracy: 0.9065
# Epoch 22/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.6549 - val_accuracy: 0.9061
# Epoch 23/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.6797 - val_accuracy: 0.9019
# Epoch 24/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.7499 - val_accuracy: 0.9049
# Epoch 25/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.7209 - val_accuracy: 0.9057
# Epoch 26/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.7468 - val_accuracy: 0.9053
# Epoch 27/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.7679 - val_accuracy: 0.9033
# Epoch 28/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.7502 - val_accuracy: 0.9048
# Epoch 29/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.7568 - val_accuracy: 0.9039
# Epoch 30/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.7989 - val_accuracy: 0.9052
# Epoch 31/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.7970 - val_accuracy: 0.8984
# Epoch 32/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.8250 - val_accuracy: 0.9054
# Epoch 33/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.8417 - val_accuracy: 0.9024
# Epoch 34/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.8219 - val_accuracy: 0.9024
# Epoch 35/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.9003 - val_accuracy: 0.8945
# Epoch 36/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.8706 - val_accuracy: 0.9026
# Epoch 37/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.9014 - val_accuracy: 0.9038
# Epoch 38/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.8609 - val_accuracy: 0.9016
# Epoch 39/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.8816 - val_accuracy: 0.9053
# Epoch 40/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.9418 - val_accuracy: 0.9037
# Epoch 41/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.8850 - val_accuracy: 0.9016
# Epoch 42/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.9279 - val_accuracy: 0.9028
# Epoch 43/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.9285 - val_accuracy: 0.9047
# Epoch 44/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.9209 - val_accuracy: 0.9031
# Epoch 45/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.9685 - val_accuracy: 0.9029
# Epoch 46/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.9558 - val_accuracy: 0.8939
# Epoch 47/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.9438 - val_accuracy: 0.9048
# Epoch 48/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.9982 - val_accuracy: 0.9034
# Epoch 49/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.9997 - val_accuracy: 0.9032
# Epoch 50/50
# 938/938 [==============================] - 32s 35ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 1.0367 - val_accuracy: 0.9043
# Train Acc      0.9983500242233276
# Validation Acc 0.9042999744415283
